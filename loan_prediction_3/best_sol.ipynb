# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %%
def encoded_feature_complete(data,obj):
    test_credit_given=data.loc[test[obj].notnull()]
    test_credit_find=data.loc[test[obj].isnull()]
    clf=RandomForestClassifier(n_estimators=200)
    clf=clf.fit(test_credit_given.drop([obj,'Loan_ID'],axis=1),test_credit_given[obj])
    test_credit_find[obj]=clf.predict(test_credit_find.drop([obj,'Loan_ID'],axis=1))

    for index,x in test_credit_find.iterrows():
        test.loc[test.Loan_ID==x.Loan_ID]=test_credit_find.loc[test_credit_find.Loan_ID==x.Loan_ID]

# %%
def direct_feature_complete(d_train,d_test,obj):
    train_credit_given=d_train.loc[d_train[obj].notnull()]
    l=LabelEncoder()
    train_credit_given[obj]=l.fit_transform(train_credit_given[obj].astype('str'))
 
    train_credit_find=d_train.loc[d_train[obj].isnull()]
    test_credit_find=d_test.loc[d_test[obj].isnull()]
    clf=RandomForestClassifier(n_estimators=200)
    clf=clf.fit(train_credit_given.drop([obj,'Loan_ID'],axis=1),train_credit_given[obj])
    test_credit_find[obj]=clf.predict(test_credit_find.drop([obj,'Loan_ID'],axis=1))
    train_credit_find[obj]=clf.predict(train_credit_find.drop([obj,'Loan_ID'],axis=1))

    test_credit_find[obj]=l.inverse_transform(test_credit_find[obj])
    train_credit_find[obj]=l.inverse_transform(train_credit_find[obj])
      
    for index,x in train_credit_find.iterrows():
        #print(train.loc[train.Loan_ID==x.values[0]])
        train.loc[train.Loan_ID==x.values[0],obj]=x.values[-1]
     
    for index,x in test_credit_find.iterrows():
        test.loc[test.Loan_ID==x.values[0],obj]=x.values[-1]
    
    test[obj]=l.transform(test[obj].astype('str'))
    train[obj]=l.transform(train[obj].astype('str'))

# %%
train=pd.read_csv('train.csv')
#train['Loan_ID']=train['Loan_ID'].apply(lambda x: int(x[-6:]))
test=pd.read_csv('test.csv')

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
dat=pd.DataFrame()
for index,x in train.iterrows():
    if "Rural" in str(x.values[-2]):
        dat=dat.append(x)
dat
# Out:
#      ApplicantIncome  CoapplicantIncome  Credit_History Dependents  \
# 1             4583.0             1508.0             1.0          1
# 13            1853.0             2840.0             1.0          0
# 18            4887.0                0.0             1.0          0
# 23            3365.0             1917.0             0.0          2
# 32            4692.0                0.0             1.0          1
# 34           12500.0             3000.0             1.0         3+
# 57            3366.0             2200.0             1.0          0
# 62            2609.0             3449.0             0.0          0
# 63            4945.0                0.0             0.0          1
# 107           7333.0                0.0             1.0          0
# 112           3572.0             4114.0             0.0          0
# 115          14583.0                0.0             1.0          1
# 118           5568.0             2142.0             1.0          0
# 120           5667.0             2667.0             1.0        NaN
# 124           4300.0             2014.0             1.0          0
# 125           3692.0                0.0             NaN          0
# 126          23803.0                0.0             1.0         3+
# 127           3865.0             1640.0             1.0          0
# 129           6080.0             2569.0             NaN          0
# 136           4583.0                0.0             1.0          0
# 139           4200.0             1430.0             1.0          2
# 140           5042.0             2083.0             1.0          2
# 148          10000.0             1666.0             1.0          0
# 150           6277.0                0.0             0.0          0
# 151           2577.0             3750.0             1.0          0
# 153           2281.0                0.0             1.0          2
# 156           6000.0                0.0             NaN          1
# 158           2980.0             2083.0             1.0          0
# 163           4167.0             1447.0             1.0          2
# 165           3707.0             3166.0             1.0          0
# ..               ...                ...             ...        ...
# 523           7948.0             7166.0             1.0          2
# 525          17500.0                0.0             1.0          2
# 530           1025.0             5500.0             NaN          0
# 532           3588.0                0.0             0.0          2
# 535           2550.0             2042.0             1.0          0
# 538           2917.0              536.0             1.0          0
# 539           6417.0                0.0             1.0         3+
# 545           2768.0             1950.0             1.0          0
# 547           2526.0             1783.0             1.0          0
# 549           2785.0             2016.0             1.0          0
# 550           6633.0                0.0             0.0          2
# 551           2492.0             2375.0             1.0          1
# 554           3593.0             4266.0             0.0          0
# 562           5923.0             2054.0             1.0          0
# 565           4467.0                0.0             NaN          0
# 567           3400.0             2500.0             0.0         3+
# 578           1782.0             2232.0             1.0          1
# 583           1880.0                0.0             NaN          1
# 584           2787.0             1917.0             0.0          1
# 585           4283.0             3000.0             1.0          1
# 593           3859.0             3300.0             1.0          0
# 595           3833.0                0.0             1.0          0
# 596           6383.0             1000.0             1.0          2
# 598           9963.0                0.0             1.0          0
# 601           2894.0             2792.0             1.0          0
# 603           3676.0             4301.0             1.0          0
# 607           3987.0             1411.0             1.0          2
# 608           3232.0             1950.0             1.0          0
# 609           2900.0                0.0             1.0          0
# 610           4106.0                0.0             1.0         3+
#
#         Education  Gender  LoanAmount  Loan_Amount_Term   Loan_ID Loan_Status  \
# 1        Graduate    Male       128.0             360.0  LP001003           N
# 13       Graduate    Male       114.0             360.0  LP001029           N
# 18   Not Graduate    Male       133.0             360.0  LP001038           N
# 23   Not Graduate     NaN       112.0             360.0  LP001050           N
# 32       Graduate    Male       106.0             360.0  LP001097           N
# 34       Graduate    Male       320.0             360.0  LP001100           N
# 57       Graduate    Male       135.0             360.0  LP001197           N
# 62   Not Graduate    Male       165.0             180.0  LP001207           N
# 63       Graduate    Male         NaN             360.0  LP001213           N
# 107  Not Graduate    Male       120.0             360.0  LP001370           N
# 112  Not Graduate    Male       152.0               NaN  LP001391           N
# 115      Graduate    Male       185.0             180.0  LP001401           Y
# 118      Graduate    Male       175.0             360.0  LP001421           N
# 120      Graduate    Male       180.0             360.0  LP001426           Y
# 124  Not Graduate    Male       194.0             360.0  LP001439           Y
# 125      Graduate  Female        93.0             360.0  LP001443           Y
# 126      Graduate     NaN       370.0             360.0  LP001448           Y
# 127      Graduate    Male         NaN             360.0  LP001449           Y
# 129      Graduate    Male       182.0             360.0  LP001465           N
# 136      Graduate  Female        84.0             360.0  LP001489           N
# 139  Not Graduate    Male       129.0             360.0  LP001493           N
# 140      Graduate    Male       185.0             360.0  LP001497           N
# 148      Graduate  Female       225.0             360.0  LP001519           N
# 150      Graduate    Male       118.0             360.0  LP001528           N
# 151      Graduate    Male       152.0             360.0  LP001529           Y
# 153  Not Graduate    Male       113.0             360.0  LP001532           N
# 156      Graduate    Male       160.0             360.0  LP001541           Y
# 158      Graduate    Male       120.0             360.0  LP001546           Y
# 163      Graduate    Male       158.0             360.0  LP001570           Y
# 165      Graduate    Male       182.0               NaN  LP001574           Y
# ..            ...     ...         ...               ...       ...         ...
# 523      Graduate    Male       480.0             360.0  LP002693           Y
# 525      Graduate    Male       400.0             360.0  LP002699           Y
# 530      Graduate    Male       216.0             360.0  LP002717           Y
# 532      Graduate    Male       110.0             360.0  LP002723           N
# 535  Not Graduate    Male       126.0             360.0  LP002732           Y
# 538  Not Graduate    Male        66.0             360.0  LP002739           N
# 539      Graduate    Male       157.0             180.0  LP002740           Y
# 545      Graduate    Male       155.0             360.0  LP002767           Y
# 547      Graduate    Male       145.0             360.0  LP002772           Y
# 549      Graduate    Male       110.0             360.0  LP002777           Y
# 550      Graduate    Male         NaN             360.0  LP002778           N
# 551  Not Graduate    Male         NaN             360.0  LP002784           Y
# 554      Graduate    Male       132.0             180.0  LP002789           N
# 562      Graduate    Male       211.0             360.0  LP002820           Y
# 565  Not Graduate    Male       120.0             360.0  LP002833           Y
# 567      Graduate    Male       123.0             360.0  LP002837           N
# 578      Graduate    Male       107.0             360.0  LP002877           Y
# 583      Graduate    Male        61.0             360.0  LP002898           N
# 584      Graduate    Male       146.0             360.0  LP002911           N
# 585      Graduate    Male       172.0              84.0  LP002912           N
# 593      Graduate    Male       142.0             180.0  LP002936           Y
# 595  Not Graduate    Male       110.0             360.0  LP002940           Y
# 596  Not Graduate    Male       187.0             360.0  LP002941           N
# 598      Graduate    Male       180.0             360.0  LP002945           Y
# 601  Not Graduate    Male       155.0             360.0  LP002950           Y
# 603      Graduate    Male       172.0             360.0  LP002958           Y
# 607  Not Graduate    Male       157.0             360.0  LP002964           Y
# 608      Graduate    Male       108.0             360.0  LP002974           Y
# 609      Graduate  Female        71.0             360.0  LP002978           Y
# 610      Graduate    Male        40.0             180.0  LP002979           Y
#
#     Married Property_Area Self_Employed
# 1       Yes         Rural            No
# 13       No         Rural            No
# 18      Yes         Rural            No
# 23      Yes         Rural            No
# 32       No         Rural           Yes
# 34       No         Rural            No
# 57      Yes         Rural            No
# 62      Yes         Rural           Yes
# 63      Yes         Rural            No
# 107      No         Rural           NaN
# 112     Yes         Rural            No
# 115     Yes         Rural            No
# 118     Yes         Rural            No
# 120     Yes         Rural            No
# 124     Yes         Rural            No
# 125      No         Rural            No
# 126     Yes         Rural            No
# 127      No         Rural            No
# 129     Yes         Rural            No
# 136     Yes         Rural            No
# 139     Yes         Rural            No
# 140     Yes         Rural            No
# 148      No         Rural            No
# 150      No         Rural            No
# 151     Yes         Rural           Yes
# 153     Yes         Rural            No
# 156     Yes         Rural            No
# 158      No         Rural           NaN
# 163     Yes         Rural            No
# 165     Yes         Rural            No
# ..      ...           ...           ...
# 523     Yes         Rural           Yes
# 525     Yes         Rural           Yes
# 530     Yes         Rural            No
# 532      No         Rural            No
# 535      No         Rural           NaN
# 538     Yes         Rural            No
# 539     Yes         Rural            No
# 545     Yes         Rural            No
# 547      No         Rural            No
# 549     Yes         Rural            No
# 550     Yes         Rural           Yes
# 551     Yes         Rural            No
# 554     Yes         Rural            No
# 562     Yes         Rural            No
# 565     Yes         Rural            No
# 567     Yes         Rural            No
# 578     Yes         Rural            No
# 583     Yes         Rural            No
# 584     Yes         Rural            No
# 585     Yes         Rural            No
# 593     Yes         Rural            No
# 595      No         Rural            No
# 596     Yes         Rural           Yes
# 598     Yes         Rural           Yes
# 601     Yes         Rural           NaN
# 603      No         Rural            No
# 607     Yes         Rural            No
# 608     Yes         Rural            No
# 609      No         Rural            No
# 610     Yes         Rural            No
#
# [179 rows x 13 columns]

# %%
#var=['Gender','Married','Education','Self_Employed','Property_Area']
var=['Education','Property_Area']
from sklearn.preprocessing import LabelEncoder

for x in var:
    l=LabelEncoder()
    train[x]=l.fit_transform(train[x].astype('str'))
    print(l.classes_)
    test[x]=l.transform(test[x].astype('str'))
# Out:
# ['Graduate' 'Not Graduate']
# ['Rural' 'Semiurban' 'Urban']

# %%
direct_feature_complete(train[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender']],test[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender']],'Gender')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
direct_feature_complete(train[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed']],test[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed']],'Self_Employed')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
l_status=LabelEncoder()
train['Loan_Status']=l_status.fit_transform(train['Loan_Status'])

# %%
direct_feature_complete(train[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents']],test[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents']],'Dependents')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
direct_feature_complete(train[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term']],test[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term']],'Loan_Amount_Term')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-bbfd820cec8f> in <module>()
# ----> 1 direct_feature_complete(train[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term']],test[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term']],'Loan_Amount_Term')
#
# <ipython-input-29-1bad0e84ec55> in direct_feature_complete(d_train, d_test, obj)
#      21         test.loc[test.Loan_ID==x.values[0],obj]=x.values[-1]
#      22
# ---> 23     test[obj]=l.transform(test[obj].astype('str'))
#      24     train[obj]=l.transform(train[obj].astype('str'))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py in transform(self, y)
#     131         if len(np.intersect1d(classes, self.classes_)) < len(classes):
#     132             diff = np.setdiff1d(classes, self.classes_)
# --> 133             raise ValueError("y contains new labels: %s" % str(diff))
#     134         return np.searchsorted(self.classes_, y)
#     135
#
# ValueError: y contains new labels: ['350.0' '6.0']

# %%
direct_feature_complete(train[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term','LoanAmount']],test[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term','LoanAmount']],'LoanAmount')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-ad068ff0bbdf> in <module>()
# ----> 1 direct_feature_complete(train[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term','LoanAmount']],test[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term','LoanAmount']],'LoanAmount')
#
# <ipython-input-29-1bad0e84ec55> in direct_feature_complete(d_train, d_test, obj)
#      21         test.loc[test.Loan_ID==x.values[0],obj]=x.values[-1]
#      22
# ---> 23     test[obj]=l.transform(test[obj].astype('str'))
#      24     train[obj]=l.transform(train[obj].astype('str'))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py in transform(self, y)
#     131         if len(np.intersect1d(classes, self.classes_)) < len(classes):
#     132             diff = np.setdiff1d(classes, self.classes_)
# --> 133             raise ValueError("y contains new labels: %s" % str(diff))
#     134         return np.searchsorted(self.classes_, y)
#     135
#
# ValueError: y contains new labels: ['147.0' '163.0' '171.0' '177.0' '183.0' '189.0' '197.0' '199.0' '212.0'
#  '213.0' '232.0' '235.0' '254.0' '256.0' '257.0' '28.0' '297.0' '336.0'
#  '390.0' '412.0' '460.0' '49.0' '550.0' '57.0' '64.0' '68.0' '77.0' '79.0'
#  '92.0']

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               614 non-null int64
# Married              611 non-null object
# Dependents           614 non-null int64
# Education            614 non-null int64
# Self_Employed        614 non-null int64
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           614 non-null object
# Loan_Amount_Term     614 non-null object
# Credit_History       564 non-null float64
# Property_Area        614 non-null int64
# Loan_Status          614 non-null int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 62.4+ KB

# %%
direct_feature_complete(train[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term','LoanAmount','Credit_History']],test[['Loan_ID','Education','Property_Area','ApplicantIncome','CoapplicantIncome','Gender','Self_Employed','Dependents','Loan_Amount_Term','LoanAmount','Credit_History']],'Credit_History')
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train=train.dropna(how='any')

# %%
train['LoanAmount']=train['LoanAmount'].astype(float)
train['Loan_Amount_Term']=train['Loan_Amount_Term'].astype(float)

test['LoanAmount']=test['LoanAmount'].astype(float)
test['Loan_Amount_Term']=test['Loan_Amount_Term'].astype(float)

# %%
l=LabelEncoder()
train['Married']=l.fit_transform(train['Married'].astype('str'))
print(l.classes_)
test['Married']=l.transform(test['Married'].astype('str'))
# Out:
# ['No' 'Yes']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesClassifier

from xgboost import XGBRegressor

#clf=RandomForestRegressor(n_estimators=200,n_jobs=-1,min_samples_leaf=3,warm_start=True, min_samples_split=4,max_features='log2')
clf = XGBRegressor(n_estimators=200,min_child_weight=5,random_state=2)
clf.fit(train.drop(['Loan_Status','Loan_ID'],axis=1),train['Loan_Status'])
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=5, missing=None, n_estimators=200,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=2,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
'''
from sklearn.cross_validation import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train.drop(['Loan_Status','Loan_ID'],axis=1),train['Loan_Status'], test_size=0.2, random_state=4242)

import xgboost as xgb

# Set our parameters for xgboost
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.11 #0.02
params['max_depth'] = 5
#params['subsample']=0.7
#params['min_child_weight']=1
#params['colsample_bytree']=0.7
params['silent']=1
#params['seed']=1632

d_train = xgb.DMatrix(x_train, label=y_train)
d_valid = xgb.DMatrix(x_valid, label=y_valid)
watchlist = [(d_train, 'train'), (d_valid, 'valid')]

bst = xgb.train(params, d_train, 1000, watchlist, early_stopping_rounds=50, verbose_eval=10)

d_test = xgb.DMatrix(test.drop(['Loan_ID'],axis=1))
p_test = bst.predict(d_test)

predict=np.round(p_test,decimals=0).astype(int)
predict=l_status.inverse_transform(predict)

sub=pd.DataFrame(test['Loan_ID'])
sub['Loan_Status']=predict
sub.to_csv('best_sub2.csv',index=False)

'''
# Out:
# "\nfrom sklearn.cross_validation import train_test_split\nx_train, x_valid, y_train, y_valid = train_test_split(train.drop(['Loan_Status','Loan_ID'],axis=1),train['Loan_Status'], test_size=0.2, random_state=4242)\n\nimport xgboost as xgb\n\n# Set our parameters for xgboost\nparams = {}\nparams['objective'] = 'binary:logistic'\nparams['eval_metric'] = 'logloss'\nparams['eta'] = 0.11 #0.02\nparams['max_depth'] = 5\n#params['subsample']=0.7\n#params['min_child_weight']=1\n#params['colsample_bytree']=0.7\nparams['silent']=1\n#params['seed']=1632\n\nd_train = xgb.DMatrix(x_train, label=y_train)\nd_valid = xgb.DMatrix(x_valid, label=y_valid)\nwatchlist = [(d_train, 'train'), (d_valid, 'valid')]\n\nbst = xgb.train(params, d_train, 1000, watchlist, early_stopping_rounds=50, verbose_eval=10)\n\nd_test = xgb.DMatrix(test.drop(['Loan_ID'],axis=1))\np_test = bst.predict(d_test)\n\npredict=np.round(p_test,decimals=0).astype(int)\npredict=l_status.inverse_transform(predict)\n\nsub=pd.DataFrame(test['Loan_ID'])\nsub['Loan_Status']=predict\nsub.to_csv('best_sub2.csv',index=False)\n\n"

# %%
predict=clf.predict(test.drop(['Loan_ID'],axis=1))

# %%
predict=np.round(predict,decimals=0).astype(int)
predict=l_status.inverse_transform(predict)
predict
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'N', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y',
#        'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'N', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y'], dtype=object)

# %%
sub=pd.DataFrame(test['Loan_ID'])
sub['Loan_Status']=predict

# %%
sub.to_csv('best_sub.csv',index=False)

# %%
import seaborn as sns
tr=train['Loan_Status']
print(train['Loan_Status'])
sns.violinplot(l_status.transform(predict))
#sns.swarmplot(np.array(tr))

plt.show()
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
# 6      1
# 7      0
# 8      1
# 9      0
# 10     1
# 11     1
# 12     1
# 13     0
# 14     1
# 15     1
# 16     1
# 17     0
# 18     0
# 19     1
# 20     0
# 21     1
# 22     0
# 23     0
# 24     0
# 25     1
# 26     1
# 27     1
# 28     0
# 29     1
#       ..
# 584    0
# 585    0
# 586    1
# 587    1
# 588    1
# 589    0
# 590    1
# 591    0
# 592    1
# 593    1
# 594    1
# 595    1
# 596    0
# 597    0
# 598    1
# 599    1
# 600    0
# 601    1
# 602    1
# 603    1
# 604    1
# 605    0
# 606    1
# 607    1
# 608    1
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 611, dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-f2397219968a> in <module>()
#       2 tr=l_status.transform(train['Loan_Status'])
#       3 print(train['Loan_Status'])
# ----> 4 sns.violinplot(l_status.transform(predict))
#       5 #sns.swarmplot(np.array(tr))
#       6
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py in transform(self, y)
#     129
#     130         classes = np.unique(y)
# --> 131         if len(np.intersect1d(classes, self.classes_)) < len(classes):
#     132             diff = np.setdiff1d(classes, self.classes_)
#     133             raise ValueError("y contains new labels: %s" % str(diff))
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py in intersect1d(ar1, ar2, assume_unique)
#     335         ar2 = unique(ar2)
#     336     aux = np.concatenate((ar1, ar2))
# --> 337     aux.sort()
#     338     return aux[:-1][aux[1:] == aux[:-1]]
#     339
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
test.info()
